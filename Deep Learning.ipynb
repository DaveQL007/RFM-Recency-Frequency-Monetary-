# %% [markdown]
# #Deep Learning - • Introduction to Neural Networks • Activation functions a)Sigmoid b) Relu c)Softmax d)Leaky Relu e)Tanh • Gradient Descent • Learning Rate and tuning • Optimization functions • Introduction to Tensorflow • Introduction to keras • Back propagation and chain rule • Fully connected layer • Cross entropy • Weight Initialization • Regularization

# %%
# !pip install tensorflow
# Out:
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\lenovo\anaconda3\lib\site-packages)

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical
import numpy as np

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Reshape and normalize
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255

# One-hot encode labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Define CNN model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# Compile and train
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 469/469 [==============================] - 29s 49ms/step - loss: 0.2338 - accuracy: 0.9331 - val_loss: 0.0837 - val_accuracy: 0.9750
# Epoch 2/5
# 469/469 [==============================] - 22s 47ms/step - loss: 0.0680 - accuracy: 0.9804 - val_loss: 0.0578 - val_accuracy: 0.9821
# Epoch 3/5
# 469/469 [==============================] - 22s 48ms/step - loss: 0.0451 - accuracy: 0.9869 - val_loss: 0.0436 - val_accuracy: 0.9863
# Epoch 4/5
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0322 - accuracy: 0.9904 - val_loss: 0.0424 - val_accuracy: 0.9857
# Epoch 5/5
# 469/469 [==============================] - 24s 50ms/step - loss: 0.0243 - accuracy: 0.9927 - val_loss: 0.0420 - val_accuracy: 0.9865

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}, Test Loss: {test_loss:.4f}")
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0420 - accuracy: 0.9865
# Test Accuracy: 0.9865, Test Loss: 0.0420

# %%
import matplotlib.pyplot as plt
import numpy as np

# Predict on first 5 test images
predictions = model.predict(x_test[:5])

for i in range(5):
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title(f"Predicted: {np.argmax(predictions[i])}, True: {np.argmax(y_test[i])}")
    plt.axis('off')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 210ms/step

# %%
# !pip install nbconvert
# Out:
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\lenovo\anaconda3\lib\site-packages)

# %%
model.save("mnist_cnn_model.h5")

# %%
# !python --version
# Out:
# Python 3.10.9

# %%
import struct
print("Python Architecture:", struct.calcsize("P") * 8, "bit")
# Out:
# Python Architecture: 64 bit

# %%
try:
    import tensorflow as tf
    print("TensorFlow version:", tf.__version__)
except ImportError as e:
    print("TensorFlow not installed.")
# Out:
# TensorFlow not installed.

# %%
# !pip uninstall -y tensorflow
# !pip install tensorflow==2.10
# Out:
# Found existing installation: tensorflow 2.10.0
# Uninstalling tensorflow-2.10.0:
#   Successfully uninstalled tensorflow-2.10.0
# ...
#   Using cached tensorflow-2.10.0-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# ...
# Using cached tensorflow-2.10.0-cp310-cp310-win_amd64.whl (455.9 MB)
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\lenovo\anaconda3\lib\site-packages)

# %%
# Force reinstall correct versions
# !pip install numpy==1.24.4 scipy==1.10.1 --force-reinstall
# Out:
# ...
#   Using cached numpy-1.24.4-cp310-cp310-win_amd64.whl.metadata (5.6 kB)
# ...
#   Using cached scipy-1.10.1-cp310-cp310-win_amd64.whl.metadata (58 kB)
# Using cached numpy-1.24.4-cp310-cp310-win_amd64.whl (14.8 MB)
# Using cached scipy-1.10.1-cp310-cp310-win_amd64.whl (42.5 MB)
# ...
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.1.3
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
# ...

# %%
    from tensorflow.keras.datasets import mnist
    import matplotlib.pyplot as plt
    import numpy as np
    from sklearn.datasets import fetch_openml
    mnist_data = fetch_openml('mnist_784', version=1, return_X_y=True)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\datasets\_openml.py:932: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
